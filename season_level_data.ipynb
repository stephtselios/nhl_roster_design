# %%
import sys
import os
import pandas as pd
import numpy as np
import datetime, time
import matplotlib.pyplot as plt
import statsmodels.api as sm
from statsmodels.formula.api import ols
from pylab import hist, show
import scipy
import zipfile


pd.set_option('display.max_rows', 50)
pd.set_option('display.max_columns', 200)

# %%
pwd
# Out:
# '/Users/stefanostselios/Desktop/nhl_roster_design-master'

# %% [markdown]
# ## import data set

# %%
dm = pd.read_csv('pbp_merged.csv')
dm = dm.drop('Unnamed: 0', axis=1)

# %% [markdown]
# - keep only regular season games and drop irrelevant observations. Exclude overtime and shootouts.

# %%
dm = dm[dm['GameNumber'] <= 21230]

# %%
dm = dm[dm['EventType']!='STOP']
dm = dm[dm['EventType']!='EISTR']
dm = dm[dm['EventType']!='EIEND']

# %%
dm = dm[dm['Period'] <= 3]
dm = dm[dm['Period'] >= 1]

# %%
dm.shape
# Out:
# (310113, 44)

# %% [markdown]
# ### reshape the data set from wide to long.

# %%
dm = dm.sort_values(['Season', 'GameNumber', 'Period', 'EventNumber'], ascending=[True, True, True, True])

# %%
a = [col for col in dm.columns if 'VPlayer' in col]
b = [col for col in dm.columns if 'HPlayer' in col]
c = [col for col in dm.columns if 'VPosition' in col]
d = [col for col in dm.columns if 'HPosition' in col]
dm = pd.lreshape(dm, {'VPlayer' : a, 'HPlayer' : b, 'VPosition' : c, 'HPosition': d})

# %%
dm.shape
# Out:
# (1796745, 24)

# %%
dm.columns
# Out:
# Index(['AdvantageType', 'EventDetail', 'EventNumber', 'EventTimeFromTwenty',
#        'EventTimeFromZero', 'EventType', 'GameDate', 'GameNumber', 'HTeamCode',
#        'Length', 'PenaltyType', 'Period', 'PlayerName', 'PlayerNumber',
#        'Season', 'ShotResult', 'ShotType', 'TeamCode', 'VTeamCode', 'Zone',
#        'VPlayer', 'HPlayer', 'VPosition', 'HPosition'],
#       dtype='object')

# %%
dm = dm.rename(columns={'PlayerNumber': 'EventPlayerNumber', 'TeamCode': 'EventTeamCode', 'PlayerName': 'EventPlayerName' })
dm = dm[['Season', 'GameNumber', 'GameDate', 'Period', 'AdvantageType', 'Zone', 'EventNumber', 'EventType', 'EventDetail', 'EventTeamCode', 'EventPlayerNumber', 'EventPlayerName', 'EventTimeFromZero', 'EventTimeFromTwenty', 'VTeamCode', 'VPlayer', 'VPosition', 'HTeamCode', 'HPlayer', 'HPosition', 'ShotType', 'ShotResult', 'Length', 'PenaltyType']]

# %%
dm = dm.sort_values(['Season', 'GameNumber', 'Period', 'EventNumber'], ascending=[True, True, True, True])

# %%
dm['AdvantageType'] = dm['AdvantageType'].fillna('EV')
dm['EventPlayerNumber'] = dm['EventPlayerNumber'].fillna('TEAM')

# %%
dm.to_csv('play_by_play.csv', index='False', sep=',')

# %% [markdown]
# #### create new data set and keep variables:
#  - (a) game number.
#  - (b) visitor team information.
#  - (c) home team information.

# %%
df = dm[['Season', 'GameNumber', 'VTeamCode', 'VPlayer', 'VPosition', 'HTeamCode', 'HPlayer', 'HPosition']]
df = df.sort_values(['Season', 'GameNumber'], ascending=[True, True])
df.head()
# Out:
#          Season  GameNumber VTeamCode  VPlayer VPosition HTeamCode  HPlayer  \
# 0          2010       20001       MTL     11.0         C       TOR     37.0
# 310113     2010       20001       MTL     21.0         R       TOR      9.0
# 620126     2010       20001       MTL     57.0         L       TOR     11.0
# 930061     2010       20001       MTL     26.0         D       TOR      3.0
# 1239931    2010       20001       MTL     75.0         D       TOR     22.0
#
#         HPosition
# 0               C
# 310113          R
# 620126          L
# 930061          D
# 1239931         D

# %%
dg = pd.read_csv('season_game_data.csv')
dg = dg.drop('Unnamed: 0', axis=1)

# %% [markdown]
# - merge season_games data on play by play data

# %%
df = pd.merge(df, dg, on=['Season', 'GameNumber', 'VTeamCode', 'HTeamCode'], how='left')
df.head()
# Out:
#    Season  GameNumber VTeamCode  VPlayer VPosition HTeamCode  HPlayer  \
# 0    2010       20001       MTL     11.0         C       TOR     37.0
# 1    2010       20001       MTL     21.0         R       TOR      9.0
# 2    2010       20001       MTL     57.0         L       TOR     11.0
# 3    2010       20001       MTL     26.0         D       TOR      3.0
# 4    2010       20001       MTL     75.0         D       TOR     22.0
#
#   HPosition  VGF  HGF  GD  VGA  HGA WinTeam LossTeam
# 0         C    2    3   1    3    2     TOR      MTL
# 1         R    2    3   1    3    2     TOR      MTL
# 2         L    2    3   1    3    2     TOR      MTL
# 3         D    2    3   1    3    2     TOR      MTL
# 4         D    2    3   1    3    2     TOR      MTL

# %% [markdown]
# - reshape the data to have home and visitor team observatons under the same coloumns.

# %%
a = [col for col in df.columns if 'Player' in col]
b = [col for col in df.columns if 'Position' in col]
c = [col for col in df.columns if 'TeamCode' in col]
d = [col for col in df.columns if 'GF' in col]
e = [col for col in df.columns if 'GA' in col]
df = pd.lreshape(df, {'PlayerNumber' : a, 'PlayerPosition' : b, 'TeamCode' : c, 'GF' : d, 'GA' : e })

# %%
df.head()
# Out:
#    GD  GameNumber LossTeam  Season WinTeam  PlayerNumber PlayerPosition  \
# 0   1       20001      MTL    2010     TOR          11.0              C
# 1   1       20001      MTL    2010     TOR          21.0              R
# 2   1       20001      MTL    2010     TOR          57.0              L
# 3   1       20001      MTL    2010     TOR          26.0              D
# 4   1       20001      MTL    2010     TOR          75.0              D
#
#   TeamCode  GF  GA
# 0      MTL   2   3
# 1      MTL   2   3
# 2      MTL   2   3
# 3      MTL   2   3
# 4      MTL   2   3

# %% [markdown]
# - import player rankings

# %%
dp = pd.read_csv('player_rank_manual.csv')
dp = dp.drop('Unnamed: 0', axis=1)

# %% [markdown]
# #### display each player by team per game. Drop duplicates.

# %%
dw = pd.merge(df, dp, on=['Season', 'TeamCode', 'PlayerNumber', 'PlayerPosition'], how='left')

# %% [markdown]
# - create column that displays the position and roster count by team per game.

# %%
dw = dw[dw.PlayerPosition!='G']
#dw = dw[dw.GameNumber==20001]
dw = dw.drop_duplicates(['Season', 'GameNumber', 'TeamCode', 'PlayerNumber'])
dw['RosterCount'] = dw.groupby(['Season', 'GameNumber', 'TeamCode'])['PlayerNumber'].transform('count')
#dw = dw[dw.RosterCount==18]
dw['Position'] = dw.apply(lambda x: 'D' if x['PlayerPosition']=='D' else 'F', 1)
dw['PositionCount'] = dw.groupby(['Season', 'GameNumber', 'TeamCode', 'Position'])['PlayerNumber'].transform('count')
dw.head()
# Out:
#    GD  GameNumber LossTeam  Season WinTeam  PlayerNumber PlayerPosition  \
# 0   1       20001      MTL    2010     TOR          11.0              C
# 1   1       20001      MTL    2010     TOR          21.0              R
# 2   1       20001      MTL    2010     TOR          57.0              L
# 3   1       20001      MTL    2010     TOR          26.0              D
# 4   1       20001      MTL    2010     TOR          75.0              D
#
#   TeamCode  GF  GA  Rank  RosterCount Position  PositionCount
# 0      MTL   2   3     2         18.0        F           12.0
# 1      MTL   2   3     1         18.0        F           12.0
# 2      MTL   2   3     2         18.0        F           12.0
# 3      MTL   2   3     2         18.0        D            6.0
# 4      MTL   2   3     2         18.0        D            6.0

# %% [markdown]
# - count the amount of forwards and defensemen by team per game.

# %%
dw['FCount'] = dw.apply(lambda x: x['PositionCount'] if x['Position']=='F' else np.NaN, 1)
dw['DCount'] = dw.apply(lambda x: x['PositionCount'] if x['Position']=='D' else np.NaN, 1)

# %%
dw['FCount'] = dw.groupby(['Season','GameNumber', 'TeamCode'])['FCount'].apply(lambda x: x.ffill().bfill())
dw['DCount'] = dw.groupby(['Season','GameNumber', 'TeamCode'])['DCount'].apply(lambda x: x.ffill().bfill())
dw.head()
# Out:
#    GD  GameNumber LossTeam  Season WinTeam  PlayerNumber PlayerPosition  \
# 0   1       20001      MTL    2010     TOR          11.0              C
# 1   1       20001      MTL    2010     TOR          21.0              R
# 2   1       20001      MTL    2010     TOR          57.0              L
# 3   1       20001      MTL    2010     TOR          26.0              D
# 4   1       20001      MTL    2010     TOR          75.0              D
#
#   TeamCode  GF  GA  Rank  RosterCount Position  PositionCount  FCount  DCount
# 0      MTL   2   3     2         18.0        F           12.0    12.0     6.0
# 1      MTL   2   3     1         18.0        F           12.0    12.0     6.0
# 2      MTL   2   3     2         18.0        F           12.0    12.0     6.0
# 3      MTL   2   3     2         18.0        D            6.0    12.0     6.0
# 4      MTL   2   3     2         18.0        D            6.0    12.0     6.0

# %% [markdown]
# ## keep games that have only 12 F and 6 D per team!!!!

# %%
dw = dw.groupby(['Season', 'GameNumber']).filter(lambda x: ((x['FCount'] == 12) & (x['DCount'] == 6)).all())

# %%
dw.shape
# Out:
# (36540, 16)

# %%
dw.to_csv('team_roster_player_rank.csv', index='False')

# %% [markdown]
# - display the mean ranking per position by team for each game.

# %%
dw = dw.groupby(['Season', 'GameNumber', 'TeamCode', 'Position', 'GF', 'GA', 'RosterCount', 'PositionCount', 'FCount', 'DCount', 'WinTeam', 'LossTeam'], as_index=False)['Rank'].mean()
dw.head(10)
# Out:
#    Season  GameNumber TeamCode Position  GF  GA  RosterCount  PositionCount  \
# 0    2010       20001      MTL        D   2   3         18.0            6.0
# 1    2010       20001      MTL        F   2   3         18.0           12.0
# 2    2010       20001      TOR        D   3   2         18.0            6.0
# 3    2010       20001      TOR        F   3   2         18.0           12.0
# 4    2010       20002      PHI        D   3   2         18.0            6.0
# 5    2010       20002      PHI        F   3   2         18.0           12.0
# 6    2010       20002      PIT        D   2   3         18.0            6.0
# 7    2010       20002      PIT        F   2   3         18.0           12.0
# 8    2010       20003      CAR        D   4   3         18.0            6.0
# 9    2010       20003      CAR        F   4   3         18.0           12.0
#
#    FCount  DCount WinTeam LossTeam      Rank
# 0    12.0     6.0     TOR      MTL  1.833333
# 1    12.0     6.0     TOR      MTL  1.833333
# 2    12.0     6.0     TOR      MTL  1.833333
# 3    12.0     6.0     TOR      MTL  1.833333
# 4    12.0     6.0     PHI      PIT  1.666667
# 5    12.0     6.0     PHI      PIT  1.583333
# 6    12.0     6.0     PHI      PIT  1.500000
# 7    12.0     6.0     PHI      PIT  1.583333
# 8    12.0     6.0     CAR      MIN  1.833333
# 9    12.0     6.0     CAR      MIN  1.750000

# %%
dw.shape
# Out:
# (4060, 13)

# %% [markdown]
# - create columns for team win and team loss.

# %%
dw['TeamWin'] =  dw.apply(lambda x: 1 if x['TeamCode']==x['WinTeam'] else 0, 1)
dw['TeamLos'] =  dw.apply(lambda x: 1 if x['TeamCode']!=x['WinTeam'] else 0, 1)
dw.head()
# Out:
#    Season  GameNumber TeamCode Position  GF  GA  RosterCount  PositionCount  \
# 0    2010       20001      MTL        D   2   3         18.0            6.0
# 1    2010       20001      MTL        F   2   3         18.0           12.0
# 2    2010       20001      TOR        D   3   2         18.0            6.0
# 3    2010       20001      TOR        F   3   2         18.0           12.0
# 4    2010       20002      PHI        D   3   2         18.0            6.0
#
#    FCount  DCount WinTeam LossTeam      Rank  TeamWin  TeamLos
# 0    12.0     6.0     TOR      MTL  1.833333        0        1
# 1    12.0     6.0     TOR      MTL  1.833333        0        1
# 2    12.0     6.0     TOR      MTL  1.833333        1        0
# 3    12.0     6.0     TOR      MTL  1.833333        1        0
# 4    12.0     6.0     PHI      PIT  1.666667        1        0

# %% [markdown]
# - display games played, games won, games loss, goals for and goals against by team for the season.

# %%
dw['GP'] = dw.groupby(['Season', 'Position', 'TeamCode'])['GameNumber'].transform('count')
dw['GW'] = dw.groupby(['Season', 'Position', 'WinTeam'])['TeamWin'].transform('sum')
dw['GL'] = dw.groupby(['Season', 'Position', 'LossTeam'])['TeamLos'].transform('sum')
dw['GF'] = dw.groupby(['Season', 'Position', 'TeamCode'])['GF'].transform('sum')
dw['GA'] = dw.groupby(['Season', 'Position', 'TeamCode'])['GA'].transform('sum')
dw.head()
# Out:
#    Season  GameNumber TeamCode Position   GF   GA  RosterCount  PositionCount  \
# 0    2010       20001      MTL        D  188  181         18.0            6.0
# 1    2010       20001      MTL        F  188  181         18.0           12.0
# 2    2010       20001      TOR        D  195  218         18.0            6.0
# 3    2010       20001      TOR        F  195  218         18.0           12.0
# 4    2010       20002      PHI        D  235  207         18.0            6.0
#
#    FCount  DCount WinTeam LossTeam      Rank  TeamWin  TeamLos  GP  GW  GL
# 0    12.0     6.0     TOR      MTL  1.833333        0        1  68  34  31
# 1    12.0     6.0     TOR      MTL  1.833333        0        1  68  34  31
# 2    12.0     6.0     TOR      MTL  1.833333        1        0  70  34  31
# 3    12.0     6.0     TOR      MTL  1.833333        1        0  70  34  31
# 4    12.0     6.0     PHI      PIT  1.666667        1        0  72  41  31

# %% [markdown]
# - create columns with the mean ranking for forward and defenseman by team per game.

# %%
dw['Rank_F'] = dw.apply(lambda x: x['Rank'] if x['Position']=='F' else np.NaN, 1)
dw['Rank_D'] = dw.apply(lambda x: x['Rank'] if x['Position']=='D' else np.NaN, 1)
dw['Rank_F'] = dw.groupby(['Season','GameNumber', 'TeamCode'])['Rank_F'].apply(lambda x: x.ffill().bfill())
dw['Rank_D'] = dw.groupby(['Season','GameNumber', 'TeamCode'])['Rank_D'].apply(lambda x: x.ffill().bfill())
dw.head()
# Out:
#    Season  GameNumber TeamCode Position   GF   GA  RosterCount  PositionCount  \
# 0    2010       20001      MTL        D  188  181         18.0            6.0
# 1    2010       20001      MTL        F  188  181         18.0           12.0
# 2    2010       20001      TOR        D  195  218         18.0            6.0
# 3    2010       20001      TOR        F  195  218         18.0           12.0
# 4    2010       20002      PHI        D  235  207         18.0            6.0
#
#    FCount  DCount WinTeam LossTeam      Rank  TeamWin  TeamLos  GP  GW  GL  \
# 0    12.0     6.0     TOR      MTL  1.833333        0        1  68  34  31
# 1    12.0     6.0     TOR      MTL  1.833333        0        1  68  34  31
# 2    12.0     6.0     TOR      MTL  1.833333        1        0  70  34  31
# 3    12.0     6.0     TOR      MTL  1.833333        1        0  70  34  31
# 4    12.0     6.0     PHI      PIT  1.666667        1        0  72  41  31
#
#      Rank_F    Rank_D
# 0  1.833333  1.833333
# 1  1.833333  1.833333
# 2  1.833333  1.833333
# 3  1.833333  1.833333
# 4  1.583333  1.666667

# %% [markdown]
# - compute the mean per position by team for the season.

# %%
dw['Mean_F']= dw.groupby(['Season', 'TeamCode'])['Rank_F'].transform('mean')
dw['Mean_D']= dw.groupby(['Season', 'TeamCode'])['Rank_D'].transform('mean')
dw.head()
# Out:
#    Season  GameNumber TeamCode Position   GF   GA  RosterCount  PositionCount  \
# 0    2010       20001      MTL        D  188  181         18.0            6.0
# 1    2010       20001      MTL        F  188  181         18.0           12.0
# 2    2010       20001      TOR        D  195  218         18.0            6.0
# 3    2010       20001      TOR        F  195  218         18.0           12.0
# 4    2010       20002      PHI        D  235  207         18.0            6.0
#
#    FCount  DCount WinTeam LossTeam      Rank  TeamWin  TeamLos  GP  GW  GL  \
# 0    12.0     6.0     TOR      MTL  1.833333        0        1  68  34  31
# 1    12.0     6.0     TOR      MTL  1.833333        0        1  68  34  31
# 2    12.0     6.0     TOR      MTL  1.833333        1        0  70  34  31
# 3    12.0     6.0     TOR      MTL  1.833333        1        0  70  34  31
# 4    12.0     6.0     PHI      PIT  1.666667        1        0  72  41  31
#
#      Rank_F    Rank_D    Mean_F    Mean_D
# 0  1.833333  1.833333  1.734069  1.825980
# 1  1.833333  1.833333  1.734069  1.825980
# 2  1.833333  1.833333  1.834524  1.888095
# 3  1.833333  1.833333  1.834524  1.888095
# 4  1.583333  1.666667  1.592593  1.571759

# %% [markdown]
# - display the quantity of wins and losses per team ( roster of 12 forwards and 6 defensemen)

# %%
dw['L'] = dw.apply(lambda x: x['GL'] if x['TeamCode']== x['LossTeam'] else (x['GP'] - x['GW']), 1)
dw['W'] = dw.apply(lambda x: x['GW'] if x['TeamCode']== x['WinTeam'] else (x['GP'] - x['GL']), 1)
dw.head()
# Out:
#    Season  GameNumber TeamCode Position   GF   GA  RosterCount  PositionCount  \
# 0    2010       20001      MTL        D  188  181         18.0            6.0
# 1    2010       20001      MTL        F  188  181         18.0           12.0
# 2    2010       20001      TOR        D  195  218         18.0            6.0
# 3    2010       20001      TOR        F  195  218         18.0           12.0
# 4    2010       20002      PHI        D  235  207         18.0            6.0
#
#    FCount  DCount WinTeam LossTeam      Rank  TeamWin  TeamLos  GP  GW  GL  \
# 0    12.0     6.0     TOR      MTL  1.833333        0        1  68  34  31
# 1    12.0     6.0     TOR      MTL  1.833333        0        1  68  34  31
# 2    12.0     6.0     TOR      MTL  1.833333        1        0  70  34  31
# 3    12.0     6.0     TOR      MTL  1.833333        1        0  70  34  31
# 4    12.0     6.0     PHI      PIT  1.666667        1        0  72  41  31
#
#      Rank_F    Rank_D    Mean_F    Mean_D   L   W
# 0  1.833333  1.833333  1.734069  1.825980  31  37
# 1  1.833333  1.833333  1.734069  1.825980  31  37
# 2  1.833333  1.833333  1.834524  1.888095  36  34
# 3  1.833333  1.833333  1.834524  1.888095  36  34
# 4  1.583333  1.666667  1.592593  1.571759  31  41

# %% [markdown]
# - compute win and loss percent by team. Drop duplicate observations.

# %%
dx = dw[['Season', 'TeamCode', 'GP', 'L', 'W', 'GF', 'GA', 'Mean_F', 'Mean_D']]
dx = dx.drop_duplicates(['Season', 'TeamCode'])
dx['WinPc'] = dx['W']/ dx['GP']
dx['LossPc'] = dx['L']/ dx['GP']
dx = dx[['Season', 'TeamCode', 'GP','W', 'L', 'GF', 'GA', 'WinPc', 'LossPc', 'Mean_F', 'Mean_D']]
dx.head()
# Out:
#    Season TeamCode  GP   W   L   GF   GA     WinPc    LossPc    Mean_F  \
# 0    2010      MTL  68  37  31  188  181  0.544118  0.455882  1.734069
# 2    2010      TOR  70  34  36  195  218  0.485714  0.514286  1.834524
# 4    2010      PHI  72  41  31  235  207  0.569444  0.430556  1.592593
# 6    2010      PIT  71  40  31  204  180  0.563380  0.436620  1.642019
# 8    2010      CAR  76  38  38  222  218  0.500000  0.500000  1.751096
#
#      Mean_D
# 0  1.825980
# 2  1.888095
# 4  1.571759
# 6  1.561033
# 8  1.804825

# %% [markdown]
# - rank teams based on win percent, mean forwards and mean defensemen.

# %%
dx['Rank_W'] = dx.groupby(['Season'])['WinPc'].rank(ascending=False)
dx['Rank_F'] = dx.groupby(['Season'])['Mean_F'].rank(ascending=True)
dx['Rank_D'] = dx.groupby(['Season'])['Mean_D'].rank(ascending=True)
dx = dx.sort_values(['Season', 'Rank_W', 'Rank_F', 'Rank_D'], ascending=[True, True, True, True])
dx.head(30)
# Out:
#       Season TeamCode  GP   W   L   GF   GA     WinPc    LossPc    Mean_F  \
# 70      2010      VAN  73  48  25  238  175  0.657534  0.342466  1.602740
# 22      2010       SJ  65  41  24  206  158  0.630769  0.369231  1.519231
# 36      2010      BOS  76  45  31  228  176  0.592105  0.407895  1.603070
# 30      2010      DET  68  40  28  220  201  0.588235  0.411765  1.636029
# 28      2010      ANA  65  38  27  186  181  0.584615  0.415385  1.608974
# 102     2010      WSH  72  42  30  190  169  0.583333  0.416667  1.613426
# 68      2010       LA  70  40  30  194  178  0.571429  0.428571  1.602381
# 4       2010      PHI  72  41  31  235  207  0.569444  0.430556  1.592593
# 6       2010      PIT  71  40  31  204  180  0.563380  0.436620  1.642019
# 42      2010      NYR  73  41  32  223  177  0.561644  0.438356  1.712329
# 38      2010      PHX  69  38  31  205  193  0.550725  0.449275  1.688406
# 0       2010      MTL  68  37  31  188  181  0.544118  0.455882  1.734069
# 12      2010      CHI  52  28  24  172  144  0.538462  0.461538  1.684295
# 32      2010      BUF  65  35  30  200  186  0.538462  0.461538  1.742308
# 62      2010      NSH  72  38  34  196  173  0.527778  0.472222  1.711806
# 16      2010      CGY  72  37  35  224  211  0.513889  0.486111  1.755787
# 48      2010      DAL  71  36  35  201  210  0.507042  0.492958  1.762911
# 8       2010      CAR  76  38  38  222  218  0.500000  0.500000  1.751096
# 2       2010      TOR  70  34  36  195  218  0.485714  0.514286  1.834524
# 10      2010      MIN  68  33  35  173  194  0.485294  0.514706  1.787990
# 118     2010       TB  38  18  20  112  126  0.473684  0.526316  1.771930
# 58      2010      STL  66  30  36  198  191  0.454545  0.545455  1.790404
# 154     2010       NJ  67  29  38  138  174  0.432836  0.567164  1.823383
# 1128    2010      ATL  50  20  30  130  170  0.400000  0.600000  1.918333
# 20      2010      CBJ  73  29  44  192  236  0.397260  0.602740  1.841324
# 34      2010      OTT  71  27  44  169  225  0.380282  0.619718  1.934272
# 82      2010      FLA  75  28  47  185  214  0.373333  0.626667  2.000000
# 50      2010      NYI  70  23  47  199  241  0.328571  0.671429  1.920238
# 18      2010      EDM  68  22  46  174  227  0.323529  0.676471  2.000000
# 14      2010      COL  64  19  45  170  233  0.296875  0.703125  1.841146
#
#         Mean_D  Rank_W  Rank_F  Rank_D
# 70    1.600457     1.0     4.0     8.0
# 22    1.535897     2.0     1.0     2.0
# 36    1.530702     3.0     5.0     1.0
# 30    1.546569     4.0     8.0     3.0
# 28    1.648718     5.0     6.0     9.0
# 102   1.571759     6.0     7.0     6.0
# 68    1.559524     7.0     3.0     4.0
# 4     1.571759     8.0     2.0     7.0
# 6     1.561033     9.0     9.0     5.0
# 42    1.680365    10.0    13.0    12.0
# 38    1.678744    11.0    11.0    11.0
# 0     1.825980    12.0    14.0    17.0
# 12    1.666667    13.5    10.0    10.0
# 32    1.700000    13.5    15.0    15.0
# 62    1.687500    15.0    12.0    13.0
# 16    1.833333    16.0    17.0    18.0
# 48    1.835681    17.0    18.0    19.0
# 8     1.804825    18.0    16.0    16.0
# 2     1.888095    19.0    23.0    25.0
# 10    1.838235    20.0    20.0    20.0
# 118   2.000000    21.0    19.0    28.5
# 58    1.840909    22.0    21.0    21.0
# 154   2.000000    23.0    22.0    28.5
# 1128  1.693333    24.0    26.0    14.0
# 20    2.000000    25.0    25.0    28.5
# 34    1.847418    26.0    28.0    23.0
# 82    1.877778    27.0    29.5    24.0
# 50    2.000000    28.0    27.0    28.5
# 18    1.921569    29.0    29.5    26.0
# 14    1.841146    30.0    24.0    22.0

# %% [markdown]
# **Crosby played 41 games, Malkin 43 and Staal 42 for Pittsburgh**

# %%
dx.to_csv('season_team_roster.csv', index='False')

# %%
dx.shape
# Out:
# (30, 14)
