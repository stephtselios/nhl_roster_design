# %% [markdown]
# # Examination of effecient NHL roster design

# %%
import sys
import os
import pandas as pd
import numpy as np
import datetime, time
import matplotlib.pyplot as plt
import statsmodels.api as sm
from statsmodels.formula.api import ols
from pylab import hist, show
import scipy

# %% [markdown]
# ## Import dataframes

# %%
dm = pd.read_csv('t_play_by_play_o.csv')
dm = dm.sort_values(['Season', 'GameNumber', 'Period', 'EventNumber'], ascending=[True, True, True, True])
dm = dm [['Season', 'GameNumber', 'EventNumber', 'Period', 'AdvantageType', 'EventTimeFromZero', 'EventTimeFromTwenty', 'EventType', 'EventDetail', 'VPlayer1', 'VPlayer1Position', 'VPlayer2', 'VPlayer2Position', 'VPlayer3', 'VPlayer3Position', 'VPlayer4', 'VPlayer4Position', 'VPlayer5', 'VPlayer5Position', 'VPlayer6', 'VPlayer6Position', 'HPlayer1', 'HPlayer1Position', 'HPlayer2', 'HPlayer2Position', 'HPlayer3', 'HPlayer3Position', 'HPlayer4', 'HPlayer4Position', 'HPlayer5', 'HPlayer5Position', 'HPlayer6', 'HPlayer6Position']]

# %%
dg = pd.read_csv('t_play_by_play_giveaway_detail_o.csv')
dg = dg.rename(columns={'GivePlayerNumber': 'PlayerNumber', 'GivePlayerLName': 'PlayerName', 'GiveTeamCode': 'TeamCode'})

# %%
dt = pd.read_csv('t_play_by_play_takeaway_detail_o.csv')
dt = dt.sort_values(['Season', 'GameNumber', 'EventNumber'], ascending=[True, True, True])
dt = dt.rename(columns={'TakePlayerNumber': 'PlayerNumber', 'TakePlayerLName': 'PlayerName', 'TakeTeamCode': 'TeamCode'})

# %%
dl = pd.read_csv('t_play_by_play_goal_detail_o.csv')
dl = dl.sort_values(['Season', 'GameNumber', 'EventNumber'], ascending=[True, True, True])
dl = dl.rename(columns={'PlayerLName': 'PlayerName'})

# %%
ds = pd.read_csv('t_play_by_play_shot_detail_o.csv')
ds = ds.sort_values(['Season', 'GameNumber', 'EventNumber'], ascending=[True, True, True])
ds = ds.rename(columns={'PlayerLName': 'PlayerName'})

# %%
dn = pd.read_csv('t_play_by_play_miss_detail_o.csv')
dn = dn.sort_values(['Season', 'GameNumber', 'EventNumber'], ascending=[True, True, True])
dn = dn.rename(columns={'PlayerLName': 'PlayerName'})

# %%
db = pd.read_csv('t_play_by_play_block_detail_o.csv')
db = db.sort_values(['Season', 'GameNumber', 'EventNumber'], ascending=[True, True, True])
db = db.rename(columns={'ShotPlayerLName': 'ShotPlayerName', 'BlockPlayerLName': 'PlayerName', 'BlockPlayerNumber': 'PlayerNumber', 'BlockTeamCode': 'TeamCode'})

# %%
dh = pd.read_csv('t_play_by_play_hit_detail_o.csv')
dh = dh.sort_values(['Season', 'GameNumber', 'EventNumber'], ascending=[True, True, True])
dh = dh.rename(columns={'HitterPlayerLName': 'HitterPlayerName', 'HitteePlayerLName': 'HitteePlayerName'})

# %%
df = pd.read_csv('t_play_by_play_faceoff_detail_o.csv')
df = df.sort_values(['Season', 'GameNumber', 'EventNumber'], ascending=[True, True, True])
df = df.rename(columns={'VPlayerLName': 'VPlayerName', 'HPlayerLName': 'HPlayerName'})

# %%
dp = pd.read_csv('t_play_by_play_penalty_detail_o.csv')
dp = dp.sort_values(['Season', 'GameNumber', 'EventNumber'], ascending=[True, True, True])
dp = dp.rename(columns={'PenaltyPlayerLName': 'PenaltyPlayerName', 'DrawnByPlayerLName': 'DrawnByPlayerName'})

# %%
dd = pd.read_csv('t_game_detail_o.csv')

# %% [markdown]
# # merge event details into play by play

# %%
len(dm)
# Out:
# 399135

# %%
dz = pd.merge(dm,dg, on=['Season', 'GameNumber', 'EventNumber'], how='left')
dz = pd.merge(dm,dt, on=['Season', 'GameNumber', 'EventNumber'], how='left')
dz = pd.merge(dm,ds, on=['Season', 'GameNumber', 'EventNumber'], how='left')
dz = pd.merge(dm,dn, on=['Season', 'GameNumber', 'EventNumber'], how='left')
dz = pd.merge(dm,db, on=['Season', 'GameNumber', 'EventNumber'], how='left')
dz = pd.merge(dm,df, on=['Season', 'GameNumber', 'EventNumber'], how='left')
dz = pd.merge(dm,dp, on=['Season', 'GameNumber', 'EventNumber'], how='left')
dz = pd.merge(dm,dl, on=['Season', 'GameNumber', 'EventNumber'], how='left')
del dl, dp, df, db, dn, ds, dt, dg

# %%
len(dm)
# Out:
# 399135

# %%
dm.columns
# Out:
# Index(['Season', 'GameNumber', 'EventNumber', 'Period', 'AdvantageType',
#        'EventTimeFromZero', 'EventTimeFromTwenty', 'EventType', 'EventDetail',
#        'VPlayer1', 'VPlayer1Position', 'VPlayer2', 'VPlayer2Position',
#        'VPlayer3', 'VPlayer3Position', 'VPlayer4', 'VPlayer4Position',
#        'VPlayer5', 'VPlayer5Position', 'VPlayer6', 'VPlayer6Position',
#        'HPlayer1', 'HPlayer1Position', 'HPlayer2', 'HPlayer2Position',
#        'HPlayer3', 'HPlayer3Position', 'HPlayer4', 'HPlayer4Position',
#        'HPlayer5', 'HPlayer5Position', 'HPlayer6', 'HPlayer6Position'],
#       dtype='object')

# %% [markdown]
# # remove irrelevant observations

# %%
dm = dm[dm['GameNumber'] <= 20002]
dm = dm[dm['EventType']!='STOP']

# %% [markdown]
# # man-advantage scenarios

# %%
value_list = ['PP', 'SH']
dm[dm['AdvantageType'].isin(value_list)]
dm = dm[dm['AdvantageType'] != 'PP']
dm = dm[dm['AdvantageType'] != 'SH']
dm['AdvantageType'] = dm['AdvantageType'].fillna('EV')

# %% [markdown]
# # generate time between events

# %%
# set_index (unit of observation: season, gn, en)
dm['TimeBetweenEvent'] = dm['EventTimeFromZero'] - dm['EventTimeFromZero'].shift(1)
dm['TimeBetweenEvent'] = dm['TimeBetweenEvent'].abs()

# %%
dm.to_csv('pbpmerge.csv', index='False', sep=',')

# %%
# Out:
#      Season  GameNumber  EventNumber  Period AdvantageType  EventTimeFromZero  \
# 0      2010       20001            1       1            EV                  0
# 68     2010       20001            3       1            EV                 15
# 67     2010       20001            4       1            EV                 46
# 66     2010       20001            5       1            EV                 57
# 41     2010       20001            6       1            EV                 69
# 21     2010       20001            7       1            EV                 73
# 90     2010       20001            8       1            EV                 86
# 89     2010       20001            9       1            EV                 91
# 20     2010       20001           10       1            EV                 95
# 74     2010       20001           11       1            EV                102
# 40     2010       20001           12       1            EV                104
# 19     2010       20001           13       1            EV                108
# 65     2010       20001           14       1            EV                125
# 64     2010       20001           15       1            EV                140
# 32     2010       20001           17       1            EV                147
# 39     2010       20001           18       1            EV                171
# 63     2010       20001           19       1            EV                221
# 38     2010       20001           20       1            EV                241
# 62     2010       20001           21       1            EV                249
# 18     2010       20001           22       1            EV                260
# 17     2010       20001           23       1            EV                267
# 31     2010       20001           25       1            EV                267
# 61     2010       20001           26       1            EV                287
# 16     2010       20001           27       1            EV                303
# 60     2010       20001           28       1            EV                305
# 88     2010       20001           29       1            EV                323
# 87     2010       20001           30       1            EV                329
# 15     2010       20001           31       1            EV                333
# 37     2010       20001           32       1            EV                374
# 86     2010       20001           33       1            EV                375
# ..      ...         ...          ...     ...           ...                ...
# 538    2010       20002          287       3            EV                650
# 591    2010       20002          288       3            EV                657
# 565    2010       20002          289       3            EV                658
# 560    2010       20002          290       3            EV                684
# 559    2010       20002          291       3            EV                686
# 590    2010       20002          292       3            EV                689
# 576    2010       20002          293       3            EV                697
# 548    2010       20002          295       3            EV                702
# 598    2010       20002          296       3            EV                763
# 575    2010       20002          297       3            EV                774
# 547    2010       20002          299       3            EV                775
# 537    2010       20002          300       3            EV                785
# 546    2010       20002          302       3            EV                809
# 536    2010       20002          303       3            EV                821
# 589    2010       20002          304       3            EV                826
# 545    2010       20002          306       3            EV                861
# 588    2010       20002          307       3            EV                868
# 564    2010       20002          308       3            EV                895
# 535    2010       20002          309       3            EV                942
# 587    2010       20002          310       3            EV                959
# 534    2010       20002          311       3            EV               1012
# 597    2010       20002          312       3            EV               1017
# 533    2010       20002          313       3            EV               1026
# 544    2010       20002          315       3            EV               1027
# 596    2010       20002          316       3            EV               1039
# 586    2010       20002          317       3            EV               1043
# 558    2010       20002          318       3            EV               1052
# 585    2010       20002          319       3            EV               1056
# 543    2010       20002          321       3            EV               1081
# 580    2010       20002          322       3            EV               1127
#
#      EventTimeFromTwenty EventType  \
# 0                   1200       FAC
# 68                  1185       HIT
# 67                  1154       HIT
# 66                  1143       HIT
# 41                  1131      GIVE
# 21                  1127     BLOCK
# 90                  1114      SHOT
# 89                  1109      SHOT
# 20                  1105     BLOCK
# 74                  1098      MISS
# 40                  1096      GIVE
# 19                  1092     BLOCK
# 65                  1075       HIT
# 64                  1060       HIT
# 32                  1053       FAC
# 39                  1029      GIVE
# 63                   979       HIT
# 38                   959      GIVE
# 62                   951       HIT
# 18                   940     BLOCK
# 17                   933     BLOCK
# 31                   933       FAC
# 61                   913       HIT
# 16                   897     BLOCK
# 60                   895       HIT
# 88                   877      SHOT
# 87                   871      SHOT
# 15                   867     BLOCK
# 37                   826      GIVE
# 86                   825      SHOT
# ..                   ...       ...
# 538                  550     BLOCK
# 591                  543      SHOT
# 565                  542       HIT
# 560                  516      GIVE
# 559                  514      GIVE
# 590                  511      SHOT
# 576                  503      MISS
# 548                  498       FAC
# 598                  437      TAKE
# 575                  426      MISS
# 547                  425       FAC
# 537                  415     BLOCK
# 546                  391       FAC
# 536                  379     BLOCK
# 589                  374      SHOT
# 545                  339       FAC
# 588                  332      SHOT
# 564                  305       HIT
# 535                  258     BLOCK
# 587                  241      SHOT
# 534                  188     BLOCK
# 597                  183      TAKE
# 533                  174     BLOCK
# 544                  173       FAC
# 596                  161      TAKE
# 586                  157      SHOT
# 558                  148      GIVE
# 585                  144      SHOT
# 543                  119       FAC
# 580                   73      PENL
#
#                                            EventDetail  VPlayer1  \
# 0    MTL won Neu. Zone - MTL #11 GOMEZ vs TOR #37 B...        11
# 68         TOR #37 BRENT HIT MTL #26 GORGES, Off. Zone        11
# 67       MTL #14 PLEKANEC HIT TOR #2 SCHENN, Off. Zone        14
# 66       MTL #76 SUBBAN HIT TOR #15 KABERLE, Neu. Zone        14
# 41          TOR&nbsp;GIVEAWAY - #35 GIGUERE, Def. Zone        14
# 21   MTL #76 SUBBAN BLOCKED BY  TOR #2 SCHENN, Wris...        14
# 90    MTL ONGOAL - #81 ELLER, Wrist, Off. Zone, 11 ft.        14
# 89   MTL ONGOAL - #46 KOSTITSYN, Snap, Off. Zone, 8...        14
# 20   MTL #76 SUBBAN BLOCKED BY  TOR #32 VERSTEEG, S...        14
# 74   MTL #76 SUBBAN, Slap, Wide of Net, Off. Zone, ...        15
# 40           MTL&nbsp;GIVEAWAY - #52 DARCHE, Neu. Zone        15
# 19   TOR #16 MACARTHUR BLOCKED BY  MTL #26 GORGES, ...        15
# 65       MTL #75 GILL HIT TOR #16 MACARTHUR, Def. Zone        15
# 64   MTL #40 LAPIERRE HIT TOR #36 GUNNARSSON, Off. ...        17
# 32   MTL won Off. Zone - MTL #17 BOYD vs TOR #84 GR...        17
# 39       TOR&nbsp;GIVEAWAY - #22 BEAUCHEMIN, Def. Zone        17
# 63     MTL #57 POULIOT HIT TOR #11 SJOSTROM, Off. Zone        11
# 38           MTL&nbsp;GIVEAWAY - #76 SUBBAN, Def. Zone        14
# 62         MTL #81 ELLER HIT TOR #3 PHANEUF, Off. Zone        14
# 18   MTL #81 ELLER BLOCKED BY  TOR #22 BEAUCHEMIN, ...        14
# 17   MTL #14 PLEKANEC BLOCKED BY  TOR #3 PHANEUF, W...        14
# 31   TOR won Def. Zone - MTL #11 GOMEZ vs TOR #84 G...        11
# 61     MTL #57 POULIOT HIT TOR #8 KOMISAREK, Off. Zone        11
# 16   TOR #84 GRABOVSKI BLOCKED BY  MTL #26 GORGES, ...        11
# 60        TOR #41 KULEMIN HIT MTL #11 GOMEZ, Off. Zone        11
# 88   TOR ONGOAL - #81 KESSEL, Wrist, Off. Zone, 25 ft.        15
# 87    TOR ONGOAL - #42 BOZAK, Wrist, Off. Zone, 12 ft.        15
# 15   TOR #2 SCHENN BLOCKED BY  MTL #76 SUBBAN, Slap...        15
# 37           MTL&nbsp;GIVEAWAY - #45 PICARD, Def. Zone        17
# 86   TOR ONGOAL - #8 KOMISAREK, Wrist, Off. Zone, 5...        17
# ..                                                 ...       ...
# 538  PHI #21 VAN RIEMSDYK BLOCKED BY  PIT #26 TANGR...        17
# 591  PHI ONGOAL - #21 VAN RIEMSDYK, Backhand, Off. ...        17
# 565  PIT #44 ORPIK HIT PHI #21 VAN RIEMSDYK, Def. Zone        17
# 560          PIT&nbsp;GIVEAWAY - #71 MALKIN, Off. Zone        17
# 559          PHI&nbsp;GIVEAWAY - #17 CARTER, Def. Zone        17
# 590   PIT ONGOAL - #44 ORPIK, Wrist, Off. Zone, 65 ft.        17
# 576  PIT #4 MICHALEK, Wrist, Wide of Net, Off. Zone...        17
# 548  PHI won Neu. Zone - PHI #48 BRIERE vs PIT #87 ...        48
# 598          PIT&nbsp;TAKEAWAY - #87 CROSBY, Def. Zone        28
# 575  PIT #14 KUNITZ, Wrist, Wide of Net, Off. Zone,...        28
# 547  PIT won Off. Zone - PHI #36 POWE vs PIT #10 LE...        36
# 537  PIT #5 ENGELLAND BLOCKED BY  PHI #28 GIROUX, W...        36
# 546  PHI won Off. Zone - PHI #17 CARTER vs PIT #25 ...        17
# 536  PHI #18 RICHARDS BLOCKED BY  PIT #4 MICHALEK, ...        17
# 589  PHI ONGOAL - #13 CARCILLO, Wrist, Off. Zone, 3...        17
# 545  PIT won Off. Zone - PHI #18 RICHARDS vs PIT #8...        17
# 588   PIT ONGOAL - #58 LETANG, Slap, Off. Zone, 55 ft.        17
# 564        PHI #11 BETTS HIT PIT #71 MALKIN, Def. Zone        11
# 535  PIT #4 MICHALEK BLOCKED BY  PHI #36 POWE, Wris...        36
# 587   PHI ONGOAL - #25 CARLE, Wrist, Off. Zone, 50 ft.        48
# 534  PIT #4 MICHALEK BLOCKED BY  PHI #21 VAN RIEMSD...        28
# 597         PIT&nbsp;TAKEAWAY - #10 LETESTU, Def. Zone        28
# 533  PIT #9 DUPUIS BLOCKED BY  PHI #25 CARLE, Slap,...        17
# 544  PIT won Off. Zone - PHI #18 RICHARDS vs PIT #8...        17
# 596          PIT&nbsp;TAKEAWAY - #71 MALKIN, Off. Zone        17
# 586  PIT ONGOAL - #87 CROSBY, Wrist, Off. Zone, 10 ft.        17
# 558         PIT&nbsp;GIVEAWAY - #4 MICHALEK, Def. Zone        17
# 585   PHI ONGOAL - #17 CARTER, Snap, Off. Zone, 14 ft.        17
# 543  PIT won Neu. Zone - PHI #48 BRIERE vs PIT #10 ...        48
# 580  PHI #11 BETTS&nbsp;Hooking(2 min), Def. Zone D...        11
#
#            ...        HPlayer2Position  HPlayer3 HPlayer3Position  HPlayer4  \
# 0          ...                       R      11.0                L       3.0
# 68         ...                       R      11.0                L       3.0
# 67         ...                       C      32.0                R       2.0
# 66         ...                       C      32.0                R       2.0
# 41         ...                       C      32.0                R       2.0
# 21         ...                       C      32.0                R       2.0
# 90         ...                       C      32.0                R       2.0
# 89         ...                       C      32.0                R       2.0
# 20         ...                       C      32.0                R       2.0
# 74         ...                       C      16.0                L       8.0
# 40         ...                       C      16.0                L       8.0
# 19         ...                       L      41.0                L       8.0
# 65         ...                       L      41.0                L       8.0
# 64         ...                       R      28.0                R       8.0
# 32         ...                       R      28.0                R       8.0
# 39         ...                       R      28.0                R       3.0
# 63         ...                       R      11.0                L       2.0
# 38         ...                       C      32.0                R       3.0
# 62         ...                       C      32.0                R       3.0
# 18         ...                       C      32.0                R       3.0
# 17         ...                       C      32.0                R       3.0
# 31         ...                       L      41.0                L       8.0
# 61         ...                       L      41.0                L       8.0
# 16         ...                       L      41.0                L       2.0
# 60         ...                       L      41.0                L       2.0
# 88         ...                       C      32.0                R       2.0
# 87         ...                       C      32.0                R       2.0
# 15         ...                       C      32.0                R       2.0
# 37         ...                       R      28.0                R       8.0
# 86         ...                       R      28.0                R       8.0
# ..         ...                     ...       ...              ...       ...
# 538        ...                       C      71.0                C       4.0
# 591        ...                       C      71.0                C       4.0
# 565        ...                       C      71.0                C       4.0
# 560        ...                       C      71.0                C       4.0
# 559        ...                       C      71.0                C       4.0
# 590        ...                       C      71.0                C       4.0
# 576        ...                       C      71.0                C       4.0
# 548        ...                       L      14.0                L       7.0
# 598        ...                       L      14.0                L       7.0
# 575        ...                       C      14.0                L       3.0
# 547        ...                       C      24.0                L       3.0
# 537        ...                       C      24.0                L       3.0
# 546        ...                       C      27.0                R       4.0
# 536        ...                       C      27.0                R       4.0
# 589        ...                       C      27.0                R       4.0
# 545        ...                       C      87.0                C       7.0
# 588        ...                       C      87.0                C       7.0
# 564        ...                       C      87.0                C       7.0
# 535        ...                       C      87.0                C       3.0
# 587        ...                       C       9.0                L       3.0
# 534        ...                       L      14.0                L       3.0
# 597        ...                       L      14.0                L       3.0
# 533        ...                       L      14.0                L       3.0
# 544        ...                       C      14.0                L       3.0
# 596        ...                       C      14.0                L       3.0
# 586        ...                       C      14.0                L       3.0
# 558        ...                       C      14.0                L       3.0
# 585        ...                       C      14.0                L       3.0
# 543        ...                       C      24.0                L       7.0
# 580        ...                       C      24.0                L       3.0
#
#     HPlayer4Position  HPlayer5 HPlayer5Position  HPlayer6 HPlayer6Position  \
# 0                  D      22.0                D      35.0                G
# 68                 D      22.0                D      35.0                G
# 67                 D      15.0                D      35.0                G
# 66                 D      15.0                D      35.0                G
# 41                 D      15.0                D      35.0                G
# 21                 D      15.0                D      35.0                G
# 90                 D      15.0                D      35.0                G
# 89                 D      15.0                D      35.0                G
# 20                 D      15.0                D      35.0                G
# 74                 D      36.0                D      35.0                G
# 40                 D      36.0                D      35.0                G
# 19                 D      36.0                D      35.0                G
# 65                 D      36.0                D      35.0                G
# 64                 D      36.0                D      35.0                G
# 32                 D      36.0                D      35.0                G
# 39                 D      22.0                D      35.0                G
# 63                 D      15.0                D      35.0                G
# 38                 D      22.0                D      35.0                G
# 62                 D      22.0                D      35.0                G
# 18                 D      22.0                D      35.0                G
# 17                 D      22.0                D      35.0                G
# 31                 D      36.0                D      35.0                G
# 61                 D      36.0                D      35.0                G
# 16                 D      15.0                D      35.0                G
# 60                 D      15.0                D      35.0                G
# 88                 D      15.0                D      35.0                G
# 87                 D      15.0                D      35.0                G
# 15                 D      15.0                D      35.0                G
# 37                 D      36.0                D      35.0                G
# 86                 D      36.0                D      35.0                G
# ..               ...       ...              ...       ...              ...
# 538                D      44.0                D      29.0                G
# 591                D      44.0                D      29.0                G
# 565                D      44.0                D      29.0                G
# 560                D      44.0                D      29.0                G
# 559                D      44.0                D      29.0                G
# 590                D      44.0                D      29.0                G
# 576                D      44.0                D      29.0                G
# 548                D      58.0                D      29.0                G
# 598                D      58.0                D      29.0                G
# 575                D       5.0                D      29.0                G
# 547                D       5.0                D      29.0                G
# 537                D       5.0                D      29.0                G
# 546                D      44.0                D      29.0                G
# 536                D      44.0                D      29.0                G
# 589                D      44.0                D      29.0                G
# 545                D      58.0                D      29.0                G
# 588                D      58.0                D      29.0                G
# 564                D      58.0                D      29.0                G
# 535                D       4.0                D      29.0                G
# 587                D       4.0                D      29.0                G
# 534                D       4.0                D      29.0                G
# 597                D       4.0                D      29.0                G
# 533                D       4.0                D      29.0                G
# 544                D       4.0                D      29.0                G
# 596                D       4.0                D      29.0                G
# 586                D       4.0                D      29.0                G
# 558                D       4.0                D      29.0                G
# 585                D       4.0                D      29.0                G
# 543                D      58.0                D      29.0                G
# 580                D      58.0                D      29.0                G
#
#      TimeBetweenEvent
# 0                 NaN
# 68               15.0
# 67               31.0
# 66               11.0
# 41               12.0
# 21                4.0
# 90               13.0
# 89                5.0
# 20                4.0
# 74                7.0
# 40                2.0
# 19                4.0
# 65               17.0
# 64               15.0
# 32                7.0
# 39               24.0
# 63               50.0
# 38               20.0
# 62                8.0
# 18               11.0
# 17                7.0
# 31                0.0
# 61               20.0
# 16               16.0
# 60                2.0
# 88               18.0
# 87                6.0
# 15                4.0
# 37               41.0
# 86                1.0
# ..                ...
# 538               4.0
# 591               7.0
# 565               1.0
# 560              26.0
# 559               2.0
# 590               3.0
# 576               8.0
# 548               5.0
# 598              61.0
# 575              11.0
# 547               1.0
# 537              10.0
# 546              24.0
# 536              12.0
# 589               5.0
# 545              35.0
# 588               7.0
# 564              27.0
# 535              47.0
# 587              17.0
# 534              53.0
# 597               5.0
# 533               9.0
# 544               1.0
# 596              12.0
# 586               4.0
# 558               9.0
# 585               4.0
# 543              25.0
# 580              46.0
#
# [430 rows x 34 columns]
